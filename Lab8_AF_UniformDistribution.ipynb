# %%
# !pip install --upgrade seaborn
# !pip install --upgrade scipy
# !pip install --upgrade numpy

# !python -m pip uninstall matplotlib
# !pip install matplotlib==3.1.3

# %%
import numpy as np, seaborn as sns, pandas as pd, scipy as sci, math
d = 0.25 
l = 4 #dist,length in wavelengths
N = 10
M = int (N/2)
totAF = 0
an = [1,9,36,84,126]
for i in range(1,M,1): 
    totAF += an[i]*np.cos((2*i-1)*(np.pi*l)*1); 
    
print(f"The total array factor AF_2M(even) for Uniform Distribution is {totAF}\n")
# Out:
# The total array factor AF_2M(even) for Uniform Distribution is 255.0
