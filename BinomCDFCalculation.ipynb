# %%
# HW2 Binom Distr. Python instead of R
# !pip install matplotlib
# !pip install scipy

# %%
from scipy.stats import binom 
n, p, a, b = 400, 0.06, 20, 25 # setting the values of n and p, [a,b] 
r_values = list(range(n + 1)) # defining the list of r values 
mean, var = binom.stats(n, p) # obtaining the mean and variance  
dist = [binom.pmf(r, n, p) for r in r_values ] # list of pmf values 
# printing the table P(X >= a && X <= b)

arrCDF = [] #populating BinomCDFArr
for i in range(a,b+1,1):
    arrCDF.append(i)
print(f"arrCDF: {arrCDF}\n")

print("x_i cdfProbBin(X=x_i)\n") 
cdfProbBin = 0
# CDF for i in range X in [a,b]
for i in range(n + 1): 
    if i in arrCDF: 
       cdfProbBin = cdfProbBin + dist[i] 
       print(f"{i}: {cdfProbBin}\n")
    if i > 25:
       break
    # print(str(r_values[i]) + "\t" + str(dist[i])) 
# printing mean and variance 
print("mean = "+str(mean)) 
print("variance = "+str(var))
print(f"cdfProbBin: {cdfProbBin}\n")
# Out:
# arrCDF: [20, 21, 22, 23, 24, 25]
#
# x_i cdfProbBin(X=x_i)
#
# 20: 0.06265538064625917
#
# 21: 0.13502329750210373
#
# 22: 0.21460001071787088
#
# 23: 0.2980782649145936
#
# 24: 0.38177853574484155
#
# 25: 0.4621307957418711
#
# mean = 24.0
# variance = 22.56
# cdfProbBin: 0.4621307957418711
